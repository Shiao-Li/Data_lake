# %%
import csv
import couchdb
import pandas as pd
import couchdb

# %%
#cause_of_deaths
dfcouchdb = pd.read_csv('cause_of_deaths.csv', encoding='utf-8')

# %%
dfcouchdb
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
#Convertir el dataframe en un diccionario
datoscouchdb = dfcouchdb.to_dict(orient='records')

#Conexion couchdb
servidorcouchdb = couchdb.Server('http://admin:admin@localhost:5984/')
dbcouchdb = servidorcouchdb['muertes_mundiales']

#Ingresar los datos en la base de datos
for documento in datoscouchdb:
    dbcouchdb.save(documento)
